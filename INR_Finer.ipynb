# %%
import torch
import torch.nn as nn
print(torch.__version__)
print(torch.cuda.is_available())
import numpy as np
from torch.utils.data import Dataset, DataLoader, random_split
import matplotlib.pyplot as plt

device = "cuda" if torch.cuda.is_available() else "cpu"
# Out:
# 2.11.0+cu128
# True

# %%
class CSVDataset(Dataset):
    def __init__(self, path):
        raw = np.loadtxt(path, delimiter=",", dtype=np.float32)
        self.X = torch.from_numpy(raw[:, :-1])
        self.y = torch.from_numpy(raw[:, -1])

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


full_train = CSVDataset("data.csv")
test_ds = CSVDataset("test.csv")
batch_size = 256
val_split = 0.05

# per-feature input normalization stats from the TRAINING inputs -> [-1, 1]
x_min = full_train.X.min(dim=0).values
x_max = full_train.X.max(dim=0).values
x_center = (x_min + x_max) / 2          # -> 0 after normalization
x_scale = (x_max - x_min) / 2           # -> +/-1 at the data extremes

# target standardization stats from the TRAINING targets -> mean 0, std 1
y_mean = full_train.y.mean().item()
y_std = full_train.y.std().item()
full_train.y = (full_train.y - y_mean) / y_std   # apply to train (and its val split)
test_ds.y = (test_ds.y - y_mean) / y_std         # apply to test with TRAIN stats

n_val = int(len(full_train) * val_split)
n_train = len(full_train) - n_val
train_ds, val_ds = random_split(
    full_train, [n_train, n_val],
    generator=torch.Generator().manual_seed(42),
)

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True, drop_last=True)
val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False, drop_last=False)
test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False, drop_last=False)

print(f"train batches: {len(train_loader)}, "
      f"val batches: {len(val_loader)}, "
      f"test batches: {len(test_loader)}")
print(f"input center: {x_center.numpy().round(3)}")
print(f"input scale : {x_scale.numpy().round(3)}")
print(f"target standardization: mean={y_mean:.4f}, std={y_std:.4f}")
# Out:
# train batches: 742, val batches: 40, test batches: 782
# input center: [0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5]
# input scale : [0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5 0.5]
# target standardization: mean=-4.1132, std=8.7022

# %%
class FinerLayer(nn.Module):
    """Linear layer followed by FINER's variable-periodic activation:
    sin(omega_0 * (|Wx+b| + 1) * (Wx+b)).

    The per-neuron scale (|Wx+b| + 1) widens the supported frequency set as the
    pre-activation magnitude grows. The first layer's bias is initialized in
    [-first_bias_scale, first_bias_scale] -- this is FINER's main knob: a larger
    bias spread pushes neurons into different frequency regimes at init. Weight
    init matches SIREN.

    Note: the effective frequency is omega_0 * (|x|+1), so for a given target a
    smaller omega_0 is needed here than in plain SIREN.
    """
    def __init__(self, in_features, out_features, bias=True,
                 is_first=False, omega_0=30, first_bias_scale=None,
                 scale_req_grad=False):
        super().__init__()
        self.omega_0 = omega_0
        self.is_first = is_first
        self.in_features = in_features
        self.scale_req_grad = scale_req_grad
        self.first_bias_scale = first_bias_scale
        self.linear = nn.Linear(in_features, out_features, bias=bias)
        self.init_weights()
        if self.first_bias_scale is not None and self.is_first:
            with torch.no_grad():
                self.linear.bias.uniform_(-self.first_bias_scale, self.first_bias_scale)

    def init_weights(self):
        with torch.no_grad():
            if self.is_first:
                self.linear.weight.uniform_(-1 / self.in_features,
                                             1 / self.in_features)
            else:
                bound = np.sqrt(6 / self.in_features) / self.omega_0
                self.linear.weight.uniform_(-bound, bound)

    def generate_scale(self, x):
        if self.scale_req_grad:
            return torch.abs(x) + 1
        with torch.no_grad():
            return torch.abs(x) + 1

    def forward(self, x):
        x = self.linear(x)
        scale = self.generate_scale(x)
        return torch.sin(self.omega_0 * scale * x)


class InputNorm(nn.Module):
    """Fixed (non-learnable) input normalization: (x - center) / scale.

    center/scale are stored as buffers, so they move with .to(device) and are
    saved in the state_dict, but receive no gradients. With center/scale fit on
    the training inputs this maps the data range onto [-1, 1] -- the range SIREN's
    first-layer init assumes -- so normalization always travels with the model.
    """
    def __init__(self, center, scale):
        super().__init__()
        self.register_buffer("center", torch.as_tensor(center, dtype=torch.float32))
        self.register_buffer("scale",  torch.as_tensor(scale,  dtype=torch.float32))

    def forward(self, x):
        return (x - self.center) / self.scale


class Finer(nn.Module):
    def __init__(self, in_features, hidden_features, hidden_layers, out_features,
                 outermost_linear=True, first_omega_0=30, hidden_omega_0=30.,
                 first_bias_scale=10, scale_req_grad=False,
                 in_center=None, in_scale=None, y_mean=0.0, y_std=1.0):
        super().__init__()

        # target standardization stats, kept as buffers so predict() can map the
        # network's standardized output back to original units (they travel with
        # .to(device) / state_dict, like InputNorm)
        self.register_buffer("y_mean", torch.tensor(float(y_mean)))
        self.register_buffer("y_std", torch.tensor(float(y_std)))

        net = []
        if in_center is not None:
            net.append(InputNorm(in_center, in_scale))   # fixed normalization, first layer

        net.append(FinerLayer(in_features, hidden_features,
                              is_first=True, omega_0=first_omega_0,
                              first_bias_scale=first_bias_scale,
                              scale_req_grad=scale_req_grad))

        for _ in range(hidden_layers):
            net.append(FinerLayer(hidden_features, hidden_features,
                                  is_first=False, omega_0=hidden_omega_0,
                                  scale_req_grad=scale_req_grad))

        if outermost_linear:
            final_linear = nn.Linear(hidden_features, out_features)
            with torch.no_grad():
                bound = np.sqrt(6 / hidden_features) / hidden_omega_0
                final_linear.weight.uniform_(-bound, bound)
            net.append(final_linear)
        else:
            net.append(FinerLayer(hidden_features, out_features,
                                  is_first=False, omega_0=hidden_omega_0,
                                  scale_req_grad=scale_req_grad))

        self.net = nn.Sequential(*net)

    def forward(self, x):
        # standardized output -- this is what the loss is computed against
        return self.net(x)

    @torch.no_grad()
    def predict(self, x):
        # de-standardize back to original target units for inference / reporting
        return self.forward(x) * self.y_std + self.y_mean

# InputNorm (10) -> first FINER layer (10->128) -> 4 FINER layers (128->128)
# -> linear output (128->1). Input normalization and target de-standardization
# are both baked into the model.
# omega_0 deliberately lower than SIREN's 30: FINER's (|x|+1) scale already
# multiplies the effective frequency, so 30 over-drives the sine here.
model = Finer(
    in_features=10,
    hidden_features=128,
    hidden_layers=4,
    out_features=1,
    outermost_linear=True,
    first_omega_0=5,
    hidden_omega_0=5.,
    first_bias_scale=None,
    scale_req_grad=False,
    in_center=x_center,
    in_scale=x_scale,
    y_mean=y_mean,
    y_std=y_std,
).to(device)

n_params = sum(p.numel() for p in model.parameters())
print(model)
print(f"\ndevice: {device} | trainable params: {n_params:,}")
# Out:
# Finer(
#   (net): Sequential(
#     (0): InputNorm()
#     (1): FinerLayer(
#       (linear): Linear(in_features=10, out_features=128, bias=True)
#     )
#     (2): FinerLayer(
#       (linear): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (3): FinerLayer(
#       (linear): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (4): FinerLayer(
#       (linear): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (5): FinerLayer(
#       (linear): Linear(in_features=128, out_features=128, bias=True)
#     )
#     (6): Linear(in_features=128, out_features=1, bias=True)
#   )
# )
#
# device: cuda | trainable params: 67,585

# %%
optim = torch.optim.Adam(lr=5e-4, params=model.parameters())

num_epochs = 150

# cosine-anneal the lr from 5e-5 down to 1e-7 over the run, stepped once per epoch
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optim, T_max=num_epochs, eta_min=1e-7)

train_hist, val_hist, lr_hist = [], [], []

step = 0
for epoch in range(num_epochs):
    model.train()
    running = 0.0
    for x, y in train_loader:
        x = x.to(device)
        y = y.to(device).view(-1, 1)          # match model output shape (B, 1)

        pred = model(x)
        loss = ((pred - y) ** 2).mean()        # MSE, as in the SIREN notebook

        optim.zero_grad()
        loss.backward()
        optim.step()

        running += loss.item()
        step += 1
    # ---- validation ----
    model.eval()
    sse, n = 0.0, 0
    with torch.no_grad():
        for x, y in val_loader:
            x = x.to(device)
            y = y.to(device).view(-1, 1)
            pred = model(x)
            sse += ((pred - y) ** 2).sum().item()
            n += y.numel()
    val_mse = sse / n
    train_mse = running / len(train_loader)

    train_hist.append(train_mse)
    val_hist.append(val_mse)
    lr_hist.append(scheduler.get_last_lr()[0])

    scheduler.step()  # decay lr after each epoch
    print(f"== epoch {epoch:2d} done | train MSE {train_mse:.5f} "
          f"| val MSE {val_mse:.5f} | lr {lr_hist[-1]:.2e}")
# Out:
# == epoch  0 done | train MSE 0.10133 | val MSE 0.03482 | lr 5.00e-04
# == epoch  1 done | train MSE 0.02682 | val MSE 0.02177 | lr 5.00e-04
# == epoch  2 done | train MSE 0.01790 | val MSE 0.01370 | lr 5.00e-04
# == epoch  3 done | train MSE 0.01285 | val MSE 0.00874 | lr 5.00e-04
# == epoch  4 done | train MSE 0.00886 | val MSE 0.00999 | lr 4.99e-04
# == epoch  5 done | train MSE 0.00624 | val MSE 0.00732 | lr 4.99e-04
# == epoch  6 done | train MSE 0.00616 | val MSE 0.00650 | lr 4.98e-04
# == epoch  7 done | train MSE 0.00587 | val MSE 0.00506 | lr 4.97e-04
# == epoch  8 done | train MSE 0.00582 | val MSE 0.00588 | lr 4.96e-04
# == epoch  9 done | train MSE 0.00467 | val MSE 0.00604 | lr 4.96e-04
# == epoch 10 done | train MSE 0.00471 | val MSE 0.00509 | lr 4.95e-04
# == epoch 11 done | train MSE 0.00400 | val MSE 0.00333 | lr 4.93e-04
# == epoch 12 done | train MSE 0.00396 | val MSE 0.00259 | lr 4.92e-04
# == epoch 13 done | train MSE 0.00351 | val MSE 0.00345 | lr 4.91e-04
# == epoch 14 done | train MSE 0.00370 | val MSE 0.00504 | lr 4.89e-04
# == epoch 15 done | train MSE 0.00311 | val MSE 0.00243 | lr 4.88e-04
# == epoch 16 done | train MSE 0.00305 | val MSE 0.00227 | lr 4.86e-04
# == epoch 17 done | train MSE 0.00299 | val MSE 0.00237 | lr 4.84e-04
# == epoch 18 done | train MSE 0.00316 | val MSE 0.00226 | lr 4.82e-04
# == epoch 19 done | train MSE 0.00219 | val MSE 0.00275 | lr 4.80e-04
# == epoch 20 done | train MSE 0.00304 | val MSE 0.00263 | lr 4.78e-04
# == epoch 21 done | train MSE 0.00234 | val MSE 0.00398 | lr 4.76e-04
# == epoch 22 done | train MSE 0.00247 | val MSE 0.00252 | lr 4.74e-04
# == epoch 23 done | train MSE 0.00234 | val MSE 0.00214 | lr 4.72e-04
# == epoch 24 done | train MSE 0.00201 | val MSE 0.00261 | lr 4.69e-04
# == epoch 25 done | train MSE 0.00231 | val MSE 0.00177 | lr 4.67e-04
# == epoch 26 done | train MSE 0.00184 | val MSE 0.00176 | lr 4.64e-04
# == epoch 27 done | train MSE 0.00193 | val MSE 0.00208 | lr 4.61e-04
# == epoch 28 done | train MSE 0.00182 | val MSE 0.00196 | lr 4.58e-04
# == epoch 29 done | train MSE 0.00182 | val MSE 0.00167 | lr 4.55e-04
# == epoch 30 done | train MSE 0.00166 | val MSE 0.00197 | lr 4.52e-04
# == epoch 31 done | train MSE 0.00162 | val MSE 0.00188 | lr 4.49e-04
# == epoch 32 done | train MSE 0.00157 | val MSE 0.00146 | lr 4.46e-04
# == epoch 33 done | train MSE 0.00151 | val MSE 0.00170 | lr 4.43e-04
# == epoch 34 done | train MSE 0.00144 | val MSE 0.00149 | lr 4.39e-04
# == epoch 35 done | train MSE 0.00141 | val MSE 0.00254 | lr 4.36e-04
# == epoch 36 done | train MSE 0.00149 | val MSE 0.00138 | lr 4.32e-04
# == epoch 37 done | train MSE 0.00120 | val MSE 0.00172 | lr 4.29e-04
# == epoch 38 done | train MSE 0.00143 | val MSE 0.00128 | lr 4.25e-04
# == epoch 39 done | train MSE 0.00115 | val MSE 0.00119 | lr 4.21e-04
# == epoch 40 done | train MSE 0.00122 | val MSE 0.00103 | lr 4.17e-04
# == epoch 41 done | train MSE 0.00117 | val MSE 0.00152 | lr 4.13e-04
# == epoch 42 done | train MSE 0.00114 | val MSE 0.00126 | lr 4.09e-04
# == epoch 43 done | train MSE 0.00110 | val MSE 0.00104 | lr 4.05e-04
# == epoch 44 done | train MSE 0.00102 | val MSE 0.00107 | lr 4.01e-04
# == epoch 45 done | train MSE 0.00099 | val MSE 0.00113 | lr 3.97e-04
# == epoch 46 done | train MSE 0.00103 | val MSE 0.00114 | lr 3.93e-04
# == epoch 47 done | train MSE 0.00083 | val MSE 0.00083 | lr 3.88e-04
# == epoch 48 done | train MSE 0.00094 | val MSE 0.00093 | lr 3.84e-04
# == epoch 49 done | train MSE 0.00095 | val MSE 0.00087 | lr 3.80e-04
# == epoch 50 done | train MSE 0.00080 | val MSE 0.00080 | lr 3.75e-04
# == epoch 51 done | train MSE 0.00081 | val MSE 0.00100 | lr 3.70e-04
# == epoch 52 done | train MSE 0.00079 | val MSE 0.00062 | lr 3.66e-04
# == epoch 53 done | train MSE 0.00080 | val MSE 0.00078 | lr 3.61e-04
# == epoch 54 done | train MSE 0.00071 | val MSE 0.00073 | lr 3.56e-04
# == epoch 55 done | train MSE 0.00070 | val MSE 0.00070 | lr 3.52e-04
# == epoch 56 done | train MSE 0.00073 | val MSE 0.00081 | lr 3.47e-04
# == epoch 57 done | train MSE 0.00065 | val MSE 0.00065 | lr 3.42e-04
# == epoch 58 done | train MSE 0.00059 | val MSE 0.00073 | lr 3.37e-04
# == epoch 59 done | train MSE 0.00064 | val MSE 0.00070 | lr 3.32e-04
# == epoch 60 done | train MSE 0.00060 | val MSE 0.00061 | lr 3.27e-04
# == epoch 61 done | train MSE 0.00059 | val MSE 0.00069 | lr 3.22e-04
# == epoch 62 done | train MSE 0.00053 | val MSE 0.00064 | lr 3.17e-04
# == epoch 63 done | train MSE 0.00056 | val MSE 0.00060 | lr 3.12e-04
# == epoch 64 done | train MSE 0.00054 | val MSE 0.00060 | lr 3.07e-04
# == epoch 65 done | train MSE 0.00046 | val MSE 0.00065 | lr 3.02e-04
# == epoch 66 done | train MSE 0.00053 | val MSE 0.00049 | lr 2.97e-04
# == epoch 67 done | train MSE 0.00046 | val MSE 0.00044 | lr 2.92e-04
# == epoch 68 done | train MSE 0.00041 | val MSE 0.00055 | lr 2.87e-04
# == epoch 69 done | train MSE 0.00043 | val MSE 0.00051 | lr 2.81e-04
# == epoch 70 done | train MSE 0.00044 | val MSE 0.00051 | lr 2.76e-04
# == epoch 71 done | train MSE 0.00037 | val MSE 0.00045 | lr 2.71e-04
# == epoch 72 done | train MSE 0.00042 | val MSE 0.00037 | lr 2.66e-04
# == epoch 73 done | train MSE 0.00035 | val MSE 0.00043 | lr 2.61e-04
# == epoch 74 done | train MSE 0.00036 | val MSE 0.00040 | lr 2.55e-04
# == epoch 75 done | train MSE 0.00033 | val MSE 0.00043 | lr 2.50e-04
# == epoch 76 done | train MSE 0.00033 | val MSE 0.00032 | lr 2.45e-04
# == epoch 77 done | train MSE 0.00033 | val MSE 0.00025 | lr 2.40e-04
# == epoch 78 done | train MSE 0.00028 | val MSE 0.00030 | lr 2.34e-04
# == epoch 79 done | train MSE 0.00030 | val MSE 0.00034 | lr 2.29e-04
# == epoch 80 done | train MSE 0.00026 | val MSE 0.00026 | lr 2.24e-04
# == epoch 81 done | train MSE 0.00027 | val MSE 0.00034 | lr 2.19e-04
# == epoch 82 done | train MSE 0.00025 | val MSE 0.00032 | lr 2.14e-04
# == epoch 83 done | train MSE 0.00024 | val MSE 0.00026 | lr 2.08e-04
# == epoch 84 done | train MSE 0.00022 | val MSE 0.00027 | lr 2.03e-04
# == epoch 85 done | train MSE 0.00022 | val MSE 0.00025 | lr 1.98e-04
# == epoch 86 done | train MSE 0.00022 | val MSE 0.00025 | lr 1.93e-04
# == epoch 87 done | train MSE 0.00019 | val MSE 0.00018 | lr 1.88e-04
# == epoch 88 done | train MSE 0.00019 | val MSE 0.00018 | lr 1.83e-04
# == epoch 89 done | train MSE 0.00019 | val MSE 0.00018 | lr 1.78e-04
# == epoch 90 done | train MSE 0.00017 | val MSE 0.00020 | lr 1.73e-04
# == epoch 91 done | train MSE 0.00017 | val MSE 0.00018 | lr 1.68e-04
# == epoch 92 done | train MSE 0.00016 | val MSE 0.00022 | lr 1.63e-04
# == epoch 93 done | train MSE 0.00015 | val MSE 0.00014 | lr 1.58e-04
# == epoch 94 done | train MSE 0.00014 | val MSE 0.00015 | lr 1.53e-04
# == epoch 95 done | train MSE 0.00013 | val MSE 0.00014 | lr 1.48e-04
# == epoch 96 done | train MSE 0.00012 | val MSE 0.00014 | lr 1.44e-04
# == epoch 97 done | train MSE 0.00012 | val MSE 0.00012 | lr 1.39e-04
# == epoch 98 done | train MSE 0.00011 | val MSE 0.00014 | lr 1.34e-04
# == epoch 99 done | train MSE 0.00011 | val MSE 0.00009 | lr 1.30e-04
# == epoch 100 done | train MSE 0.00010 | val MSE 0.00012 | lr 1.25e-04
# == epoch 101 done | train MSE 0.00009 | val MSE 0.00011 | lr 1.21e-04
# == epoch 102 done | train MSE 0.00009 | val MSE 0.00009 | lr 1.16e-04
# == epoch 103 done | train MSE 0.00008 | val MSE 0.00009 | lr 1.12e-04
# == epoch 104 done | train MSE 0.00008 | val MSE 0.00009 | lr 1.07e-04
# == epoch 105 done | train MSE 0.00007 | val MSE 0.00008 | lr 1.03e-04
# == epoch 106 done | train MSE 0.00007 | val MSE 0.00008 | lr 9.89e-05
# == epoch 107 done | train MSE 0.00007 | val MSE 0.00008 | lr 9.48e-05
# == epoch 108 done | train MSE 0.00006 | val MSE 0.00006 | lr 9.07e-05
# == epoch 109 done | train MSE 0.00006 | val MSE 0.00006 | lr 8.67e-05
# == epoch 110 done | train MSE 0.00005 | val MSE 0.00006 | lr 8.28e-05
# == epoch 111 done | train MSE 0.00005 | val MSE 0.00006 | lr 7.89e-05
# == epoch 112 done | train MSE 0.00005 | val MSE 0.00006 | lr 7.52e-05
# == epoch 113 done | train MSE 0.00004 | val MSE 0.00005 | lr 7.15e-05
# == epoch 114 done | train MSE 0.00004 | val MSE 0.00005 | lr 6.78e-05
# == epoch 115 done | train MSE 0.00004 | val MSE 0.00004 | lr 6.43e-05
# == epoch 116 done | train MSE 0.00004 | val MSE 0.00005 | lr 6.08e-05
# == epoch 117 done | train MSE 0.00003 | val MSE 0.00004 | lr 5.75e-05
# == epoch 118 done | train MSE 0.00003 | val MSE 0.00004 | lr 5.42e-05
# == epoch 119 done | train MSE 0.00003 | val MSE 0.00004 | lr 5.10e-05
# == epoch 120 done | train MSE 0.00003 | val MSE 0.00004 | lr 4.78e-05
# == epoch 121 done | train MSE 0.00003 | val MSE 0.00003 | lr 4.48e-05
# == epoch 122 done | train MSE 0.00002 | val MSE 0.00003 | lr 4.19e-05
# == epoch 123 done | train MSE 0.00002 | val MSE 0.00003 | lr 3.90e-05
# == epoch 124 done | train MSE 0.00002 | val MSE 0.00003 | lr 3.63e-05
# == epoch 125 done | train MSE 0.00002 | val MSE 0.00003 | lr 3.36e-05
# == epoch 126 done | train MSE 0.00002 | val MSE 0.00003 | lr 3.10e-05
# == epoch 127 done | train MSE 0.00002 | val MSE 0.00003 | lr 2.85e-05
# == epoch 128 done | train MSE 0.00002 | val MSE 0.00002 | lr 2.62e-05
# == epoch 129 done | train MSE 0.00002 | val MSE 0.00002 | lr 2.39e-05
# == epoch 130 done | train MSE 0.00002 | val MSE 0.00002 | lr 2.17e-05
# == epoch 131 done | train MSE 0.00001 | val MSE 0.00002 | lr 1.96e-05
# == epoch 132 done | train MSE 0.00001 | val MSE 0.00002 | lr 1.77e-05
# == epoch 133 done | train MSE 0.00001 | val MSE 0.00002 | lr 1.58e-05
# == epoch 134 done | train MSE 0.00001 | val MSE 0.00002 | lr 1.40e-05
# == epoch 135 done | train MSE 0.00001 | val MSE 0.00002 | lr 1.23e-05
# == epoch 136 done | train MSE 0.00001 | val MSE 0.00002 | lr 1.08e-05
# == epoch 137 done | train MSE 0.00001 | val MSE 0.00002 | lr 9.31e-06
# == epoch 138 done | train MSE 0.00001 | val MSE 0.00002 | lr 7.95e-06
# == epoch 139 done | train MSE 0.00001 | val MSE 0.00002 | lr 6.70e-06
# == epoch 140 done | train MSE 0.00001 | val MSE 0.00002 | lr 5.56e-06
# == epoch 141 done | train MSE 0.00001 | val MSE 0.00002 | lr 4.53e-06
# == epoch 142 done | train MSE 0.00001 | val MSE 0.00002 | lr 3.60e-06
# == epoch 143 done | train MSE 0.00001 | val MSE 0.00001 | lr 2.78e-06
# == epoch 144 done | train MSE 0.00001 | val MSE 0.00001 | lr 2.07e-06
# == epoch 145 done | train MSE 0.00001 | val MSE 0.00001 | lr 1.47e-06
# == epoch 146 done | train MSE 0.00001 | val MSE 0.00001 | lr 9.77e-07
# == epoch 147 done | train MSE 0.00001 | val MSE 0.00001 | lr 5.93e-07
# == epoch 148 done | train MSE 0.00001 | val MSE 0.00001 | lr 3.19e-07
# == epoch 149 done | train MSE 0.00001 | val MSE 0.00001 | lr 1.55e-07

# %%
epochs = range(1, len(train_hist) + 1)

fig, ax1 = plt.subplots(figsize=(7, 4.5))

ax1.plot(epochs, train_hist, "-o", label="train MSE", color="tab:blue")
ax1.plot(epochs, val_hist,   "-o", label="val MSE",   color="tab:orange")
ax1.set_xlabel("epoch")
ax1.set_ylabel("MSE")
ax1.set_yscale("log")          # log scale makes the decay easier to read
ax1.grid(True, alpha=0.3)

# overlay the learning-rate schedule on a second axis
ax2 = ax1.twinx()
ax2.plot(epochs, lr_hist, "--", color="tab:green", alpha=0.7, label="lr")
ax2.set_ylabel("learning rate")
ax2.set_yscale("log")

# merge legends from both axes
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc="upper right")

plt.title("SIREN training: loss curves & lr schedule")
plt.tight_layout()
plt.show()

# %%
model.eval()
N = len(test_loader.dataset)
preds = np.empty(N, dtype=np.float64)
trues = np.empty(N, dtype=np.float64)

i = 0
with torch.no_grad():
    for x, y in test_loader:
        x = x.to(device)
        out = model.predict(x).view(-1).cpu().numpy()      # original target units
        b = out.shape[0]
        preds[i:i + b] = out
        trues[i:i + b] = (y * y_std + y_mean).view(-1).numpy()  # de-standardize target
        i += b

err = preds - trues
mse = np.mean(err ** 2)
rmse = np.sqrt(mse)
mae = np.mean(np.abs(err))
r2 = 1 - np.sum(err ** 2) / np.sum((trues - trues.mean()) ** 2)

print(f"Test set ({N} samples), original units")
print(f"  MSE  : {mse:.4f}")
print(f"  RMSE : {rmse:.4f}")
print(f"  MAE  : {mae:.4f}")
print(f"  R^2  : {r2:.4f}")

# parity plot: predicted vs true (subsampled for clarity)
rng = np.random.default_rng(0)
idx = rng.choice(N, size=min(5000, N), replace=False)
lo, hi = trues.min(), trues.max()

plt.figure(figsize=(5, 5))
plt.scatter(trues[idx], preds[idx], s=4, alpha=0.3)
plt.plot([lo, hi], [lo, hi], "r--", lw=1, label="ideal")
plt.xlabel("true")
plt.ylabel("predicted")
plt.title("Test: predicted vs true")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Test set (200000 samples), original units
#   MSE  : 0.0006
#   RMSE : 0.0245
#   MAE  : 0.0186
#   R^2  : 1.0000
